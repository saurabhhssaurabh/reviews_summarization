# %%
import os
import json
import re
import string
import pandas as pd

from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer, WordNetLemmatizer

stop_words = stopwords.words('english')
stemmer_ss = SnowballStemmer("english") 
lemmatizer = WordNetLemmatizer()

# %%
def read_file(file):
    reviews = []
    for line in open(file, 'r'):
        reviews.append(json.loads(line))
        
    return pd.DataFrame(reviews)

def drop_duplicates(df, subset=['review']):
    return df.drop_duplicates(subset=subset)

def remove_punctuation(text):
    return "".join([char for char in text if char not in string.punctuation])

def remove_numbers(text):
    return re.sub(r'\d+', '', text)

def basic_processing(df):
    df['review'] = df.apply(lambda x: x['review'].lower(), axis=1)
    df['review_remove_numbers'] = df.apply(lambda x: remove_numbers(x['review']), axis=1)
    df['review_remove_numbers+symbols'] = df.apply(lambda x: remove_punctuation(x['review_remove_numbers']), axis=1)
    
    df['tokens'] = df.apply(lambda x: word_tokenize(x['review_remove_numbers+symbols']), axis=1)
    df['tokens'] = df.apply(lambda x: [i for i in x['tokens'] if i not in stop_words], axis=1)
    df['reviews_remove_numbers+symbols+stopwords'] = df.apply(lambda x: " ".join(x['tokens']), axis=1)

    df['tokens1'] = df.apply(lambda x:[lemmatizer.lemmatize(word) for word in x['tokens']], axis=1)
    df['reviews_remove_numbers+symbols+stopwords+lemmatization'] = df.apply(lambda x: " ".join(x['tokens1']), axis=1)
    
    df['tokens1'] = df.apply(lambda x:[stemmer_ss.stem(word) for word in x['tokens']], axis=1)
    df['reviews_remove_numbers+symbols+stopwords+stemming'] = df.apply(lambda x: " ".join(x['tokens1']), axis=1)

    return df.drop(columns=['tokens', 'tokens1'])

# %%
df = read_file('../dataset/b0013frnkg.json')
df = drop_duplicates(df)
df = basic_processing(df)
df.head()
# Out:
#    rating  product_id                                             review  \
# 0     5.0  B0013FRNKG  have ipad 1 and will probably get the ipad 2 b...
# 1     4.0  B0013FRNKG  so after picking it up friday and playing arou...
# 2     4.0  B0013FRNKG  the ipad2 is a great device but the same model...
# 3     4.0  B0013FRNKG  for anyone out there who is considering whethe...
# 6     4.0  B0013FRNKG  first things first: i consider myself relative...
#
#                                review_remove_numbers  \
# 0  have ipad  and will probably get the ipad  but...
# 1  so after picking it up friday and playing arou...
# 2  the ipad is a great device but the same model ...
# 3  for anyone out there who is considering whethe...
# 6  first things first: i consider myself relative...
#
#                        review_remove_numbers+symbols  \
# 0  have ipad  and will probably get the ipad  but...
# 1  so after picking it up friday and playing arou...
# 2  the ipad is a great device but the same model ...
# 3  for anyone out there who is considering whethe...
# 6  first things first i consider myself relativel...
#
#             reviews_remove_numbers+symbols+stopwords  \
# 0  ipad probably get ipad seriously would pay wai...
# 1  picking friday playing around weekend whats fi...
# 2  ipad great device model much cheaper elsewhere...
# 3  anyone considering whether make leap purchase ...
# 6  first things first consider relatively unbiase...
#
#   reviews_remove_numbers+symbols+stopwords+lemmatization  \
# 0  ipad probably get ipad seriously would pay wai...
# 1  picking friday playing around weekend whats fi...
# 2  ipad great device model much cheaper elsewhere...
# 3  anyone considering whether make leap purchase ...
# 6  first thing first consider relatively unbiased...
#
#    reviews_remove_numbers+symbols+stopwords+stemming
# 0  ipad probabl get ipad serious would pay wait b...
# 1  pick friday play around weekend what final wor...
# 2  ipad great devic model much cheaper elsewher e...
# 3  anyon consid whether make leap purchas ipad re...
# 6  first thing first consid relat unbias appl pro...
